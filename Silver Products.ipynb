# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ## Data Reading

# %%
df= spark.read.format("parquet")\
  .load("abfss://bronze@databricksprojectanushaa.dfs.core.windows.net/products")

# %%
df.createOrReplaceTempView("products")

# %%
# %sql
CREATE OR REPLACE FUNCTION databricks_cat.bronze.discount_func(p_price DOUBLE)
LANGUAGE SQL
RETURN p_price * 0.90

# %%
df

# %%
df.write.mode("overwrite").format("delta").save("abfss://silver@databricksprojectanushaa.dfs.core.windows.net/products")

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cat.silver.products_silver
USING DELTA 
LOCATION 'abfss://silver@databricksprojectanushaa.dfs.core.windows.net/products'
