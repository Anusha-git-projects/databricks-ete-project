# %%
df = spark.read.table("databricks_cat.bronze.regions")

# %%
df.display()

# %%
df.write.mode("overwrite")\
  .format("delta")\
  .save("abfss://silver@databricksprojectanushaa.dfs.core.windows.net/regions")

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cat.silver.customers_silver
USING DELTA 
LOCATION 'abfss://silver@databricksprojectanushaa.dfs.core.windows.net/customers'

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cat.silver.regions_silver
USING DELTA 
LOCATION 'abfss://silver@databricksprojectanushaa.dfs.core.windows.net/regions'
